# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/tweets_word_count.csv")

# %%
df.head()
# Out:
#                    id          handle  \
# 0  780925634159796224  HillaryClinton
# 1  780916180899037184  HillaryClinton
# 2  780911564857761793  HillaryClinton
# 3  780907038650068994  HillaryClinton
# 4  780897419462602752  HillaryClinton
#
#                                                 text  is_retweet  \
# 0  The question in this election: Who can put the...       False
# 1  Last night, Donald Trump said not paying taxes...        True
# 2  Couldn't be more proud of @HillaryClinton. Her...        True
# 3  If we stand together, there's nothing we can't...       False
# 4  Both candidates were asked about how they'd co...       False
#
#   original_author                 time in_reply_to_screen_name  \
# 0             NaN  2016-09-28T00:22:34                     NaN
# 1        timkaine  2016-09-27T23:45:00                     NaN
# 2           POTUS  2016-09-27T23:26:40                     NaN
# 3             NaN  2016-09-27T23:08:41                     NaN
# ...

# %% [markdown]
# # Assign themes by each quadrant

# %%
theme_map = {}

# %%
avg_miw_occur = df.groupby("most_important_word").mean(numeric_only=True)[["tweet_length", "miw_occurrence"]]

# %%
avg_miw_occur
# Out:
#                      tweet_length  miw_occurrence
# most_important_word
# 2nd                     26.333333        6.000000
# 3pm                     21.333333        7.222222
# 7pm                     16.800000        5.000000
# 8p                      16.666667        9.000000
# abc                     21.444444        9.000000
# ...                           ...             ...
# young                   18.500000        6.000000
# youre                   21.250000        4.000000
# youve                   20.857143        7.000000
# zero                    31.000000        2.000000
# zika                    22.000000        2.000000
#
# [1054 rows x 2 columns]

# %%
# Quadrant 1 -> More common words with short tweet length
quadrant_1 = avg_miw_occur[(avg_miw_occur.miw_occurrence >= 10) & (avg_miw_occur.tweet_length <= 17)]
quadrant_1.shape
# Out:
# (28, 2)

# %%
q1_miw = list(set(quadrant_1.index))

# %%
q1_hashtag = ['fitn',
 'supertuesday',
 'crookedhillary',
 'americafirst',
 'imwithyou',
 'iacaucus',
 'makeamericagreatagain',
 'votetrump',
 'inprimary',
 'wiprimary',
 'trumppence16',
 'trump2016',
 'oreillyfactor',
 'nyprimary']

q1_interaction = [
 'video',
 'thank',
 'west',
 'pennsylvania',
 'york',
 'south',
 'arizona',
 'realdonaldtrump',
 'donaldjtrumpjr',
 'birthday',
 'makeamericagreatagain',
 'seanhannity',
 'foxandfriends',
 'votetrump',
 'poll',
 ]

q1_target = ['make'
]

# %%
# Quadrant 2 - More common words with longer tweet length
quadrant_2 = avg_miw_occur[(avg_miw_occur.miw_occurrence >= 10) & (avg_miw_occur.tweet_length > 17)]
quadrant_2.shape
# Out:
# (83, 2)

# %%
q2_miw = list(set(quadrant_2.index))

# %%
q2_target = [
 'paying',
 'casinos',
 'built',
 'comes',
 'proven',
 'bigotry',
 'released',
 'corrupt',
 'clean',
 'better',
 'destroy',
 'sick',
 'bought',
 'believes',
 'disgrace',
 'elected',
 'maybe',
 'judgment',
 'risk',
 'let',
 'easily',
 'whos']

q2_interaction = ['philadelphia',
 'tbt',
 'voter',
 'elizabethforma',
 'vote',
 'citizen',
 'tedcruz',
 'people',
 'folks',
 'new',
 'island',
 'chris',
 'citizens',
 'register',
 'cnn',
 'nbc',
 'michigan',
 'america',
 'man',
 'great',
 'process',
 'breaks',
 'lobby',
 'day',
 'miss',
 'potential',
 'employees',
 'pres',
 'kansas',
 'judgment',
 'women',
 'comments',
 'society',
 'congrats',
 'melaniatrump',
 'registered',
 'pm']

q2_policy = ['border',
 'global',
 'student',
 'girl',
 'thousand',
 'ways',
 'para',
 'future',
 'progressive',
 'communities',
 'hall',
 'greatly',
 'lift',
 'arena',
 'president',
 'enforcement',
 'mind',
 'situation',
 'powerful',
 'board',
 'announced',
 'facts',
 'continue',
 'chip',
 'china']

# %%
# Quadrant 3 - Less common words with short tweet length
quadrant_3 = avg_miw_occur[(avg_miw_occur.miw_occurrence < 10) & (avg_miw_occur.tweet_length <= 17)]
quadrant_3.shape
# Out:
# (119, 2)

# %%
q3_miw = list(set(quadrant_3.index))

# %%
q3_hashtag = [
 'debates2016',
 'morningjoe',
 'trumptrain',
 'caucusfortrump',
 'rncincle',
 'debatenight',
 'gopdebate',
 'maga']

q3_interaction = ['questions',
 'rt',
 'watched',
 'exciting',
 'tomorrow',
 'erictrump',
 'wisconsin',
 'foxnews',
 'interviewed',
 'leaving',
 'kentucky',
 'kind',
 'follow',
 'todays',
 'ohio',
 'presidential',
 'maryland',
 'primary',
 'ago',
 'ivankatrump',
 'iowa',
 'wow',
 'hampshire',
 'facebook',
 'debate',
 'total',
 'megynkelly',
 'things',
 'greta',
 '8p',
 'office',
 'morningjoe',
 'thanks',
 'live',
 'morning',
 'foundation',
 'john',
 'enjoy',
 'vs',
 'support',
 'congratulations',
 'nevada',
 'louisiana',
 'las',
 'connecticut',
 'stage',
 'white',
 'texas',
 'north',
 'georgia',
 'safe',
 'week',
 'happy',
 'nights',
 'watch',
 'virginia',
 'thirty',
 'read',
 'election',
 'story',
 'forward',
 'governor',
 'washington',
 'lets',
 'california',
 'home',
 'indiana',
 'tickets',
 'soon',
 'high',
 'interesting',
 'florida',
 'making',
 'ready',
 'watching',
 'team',
 'address',
 'message',
 'debatenight',
 'gopdebate',
 '7pm',
 'barack',
 'history',
 'save',
 'amazing']

q3_policy = ['russia',
 'statement',
 'military',
 'mexico',
 'working',
 'raise',
 'learn',
 'response',
 'security',
 'energy',
 'reform',
 'knows',
 'stronger']

q3_target = ['hillarys',
 'literally',
 'hillaryclinton',
 'lightweight',
 'heading',
 'victory',
 'lie',
 'said',
 'remember',
 'crooked',
 'isnt',
 'hillary',
 'needs',
 'agree',
 'makes',
 'dishonest']

# %%
# Quadrant 4 - Less common words with longer tweet length
quadrant_4 = avg_miw_occur[(avg_miw_occur.miw_occurrence < 10) & (avg_miw_occur.tweet_length > 17)]
quadrant_4.shape
# Out:
# (824, 2)

# %%
q4_miw = list(set(quadrant_4.index))

# %%
q4_policy = [
 'community',
 'change',
 'justice',
 'obamacare',
 'illegal',
 'add',
 'tax',
 'police',
 'union',
 'manufacturing',
 'benefits',
 'disabilities',
 'fighting',
 'control',
 'iraq',
 'obamas',
 'iran',
 'university',
 'climate',
 'freedom',
 'opportunity',
 'racism',
 'muslim',
 'puerto',
 'nuclear',
 'increase',
 'terrorist',
 'policy',
 'middleclass',
 'plans',
 'education',
 'brexit',
 'abortion',
 'access',
 'amendment',
 'speech',
 'voice',
 'immigration',
 'muslims',
 'gun',
 'veterans',
 'criminal',
 'crisis',
 'economic',
 'ban',
 'business',
 'prisoners',
 'congress',
 'crime',
 'hed',
 'discrimination',
 'conference',
 'agenda',
 'country',
 'equality',
 'foreign',
 'politics',
 'systemic',
 'terrorism',
 'rights',
 'housing',
 'wage',
 'violence',
 'taxes',
 'refugees',
 'financial',
 'workers',
 'college',
 'prevent',
 'victims',
 'progress',
 'heard',
 'mexican',
 'discuss',
 'job',
 'divisive',
 'heritage',
 'guns',
 'affordable',
 'nato',
 'poverty',
 'killing',
 'decisions',
 'growth',
 'weapons',
 'pay',
 'school',
 'immigrants',
 'policies',
 'building',
 'nra',
 'killed',
 'war',
 'borders',
 'walls',
 'schools',
 'health']

q4_target = [
 'unbelievable',
 'gone',
 'youre',
 'got',
 'wrong',
 'held',
 'little',
 'biggest',
 'radical',
 'supreme',
 'low',
 'divided',
 'hurt',
 'disgusting',
 'clinton',
 'cruz',
 'color',
 'dollars',
 'anymore',
 'true',
 'trust',
 'endorses',
 'apart',
 'demand',
 'zero',
 'mr',
 'challenges',
 'everybody',
 'senate',
 'action',
 'rigged',
 'law',
 'tough',
 'general',
 'disaster',
 'thousands',
 'hours',
 'set',
 'public',
 'worse',
 'lost',
 'lyin',
 'angry',
 'hateful',
 'afraid',
 'doubt',
 'protect',
 'clintons',
 'billionaires',
 'money',
 'officers',
 'fund',
 'tonights',
 'wall',
 'wednesday',
 'heres',
 'vision',
 'secret',
 'short',
 'build',
 'obama',
 'secretary',
 'wait',
 'weeks',
 'late',
 'list',
 'divides',
 'going',
 'children',
 'didnt',
 'stay',
 'eighteen',
 'question',
 'orlando',
 'speaks',
 'plan',
 'theyre',
 'thing',
 'buy',
 'atlantic',
 'dnc',
 'crazy',
 'poor',
 'strong',
 'trump',
 'giving',
 'joe',
 'winning',
 'respect',
 'courage',
 'khan',
 'personal',
 'hate',
 'use',
 'repeal',
 'potus',
 'tonight',
 'companies',
 'court',
 'calls',
 'packed',
 'seriously',
 'spent',
 'returns',
 'nominee',
 'running',
 'chance',
 'youve',
 'groups',
 'fact',
 'homes',
 'cut',
 'pushing',
 'yes',
 'endorsement',
 'wages',
 'latino',
 'gets',
 'hell',
 'absolutely',
 'horrible',
 'por',
 'big',
 'corybooker',
 'ny',
 'pa',
 'nytimes',
 'rate',
 'reality',
 'given',
 'massive',
 'champion',
 'allowed',
 'goofy',
 'happening',
 'votes',
 'told',
 'stand',
 'demsinphilly',
 'went',
 'stop',
 'talks',
 'delegates',
 'mother',
 'spirit',
 'november',
 'qualified',
 'womens',
 'endorsed',
 'shouldnt',
 'check',
 'mom',
 'worst',
 'serve',
 'biased',
 'honor',
 'bad',
 'right',
 'ask',
 'rnc',
 'post',
 'end',
 'sent',
 'unfair',
 'meet',
 'path',
 'win',
 'common',
 'tried',
 'faith',
 'endorse',
 'like',
 'really',
 'credit',
 'badly',
 'sobre',
 'smart',
 'evening',
 'clue',
 'fl',
 'campaign',
 'eric',
 'boring',
 'met',
 'night',
 'jeb',
 'hope',
 'joke',
 'lying',
 'party',
 'street',
 'elizabeth',
 'succeed',
 'jobs',
 'attacked',
 'card',
 'caucus',
 'know',
 'guy',
 'berniesanders',
 'saw',
 'taken',
 'emails',
 'finally',
 'donaldtrump',
 'committed',
 'leads',
 'thats',
 'major',
 'hotel',
 'chelseaclinton',
 'establishment',
 'federal',
 'tell',
 'ahead',
 'insults',
 'called',
 'families',
 'nation',
 'worth',
 'racist',
 'turn',
 'donald',
 'barriers',
 'mental',
 'totally',
 'success',
 'heart',
 'way',
 'release',
 'usa',
 'young',
 'fired',
 'time',
 'idea',
 'mike',
 'thoughts',
 'pence',
 'fight',
 'planned',
 'false',
 'year',
 'marco',
 'defend',
 'flotus',
 'words',
 'line',
 'expected',
 'wins',
 'paul',
 'refuses',
 'proud',
 'special',
 'star',
 'room',
 'terrible',
 'mikepence',
 'unlike',
 'wont',
 'arent',
 'graham',
 'lied',
 'members',
 'course',
 'ms',
 'problems',
 'jebbush',
 'grateful',
 'tuesday',
 'leading',
 'husband',
 'speaking',
 'getting',
 'super',
 'highest',
 'wouldnt',
 'laws',
 'lot',
 'unfit',
 'defeat',
 'listen',
 'looking',
 'means',
 'pocahontas',
 'afford',
 'trumps',
 'hard',
 'voted',
 'sure',
 'come',
 'numbers',
 'accept',
 'join',
 'decision',
 'june',
 'lives',
 'say',
 'truth',
 'tune',
 'canada',
 'judgement',
 'born',
 'early',
 'trail',
 'supported',
 'twitter',
 'despite',
 'long',
 'imagine',
 'et',
 'saying',
 'house',
 'deserve',
 'prayers',
 'coming',
 'rhetoric',
 'asked',
 'united',
 'imwithher',
 'vets',
 'days',
 'results',
 'grow',
 'actually',
 'political',
 'waste',
 'afternoon',
 'melania',
 'countries',
 'feel',
 'republican',
 'threat',
 'written',
 'ballot',
 'native',
 'account',
 'reporting',
 'fraud',
 'need',
 'negative',
 'stories',
 'americas',
 'network',
 'demconvention',
 'harder',
 'hear',
 'terror']

q4_interaction =  ['ratings',
 'today',
 'mayor',
 'mate',
 'helped',
 'pick',
 'using',
 'thinking',
 'instead',
 'state',
 'republicans',
 'michael',
 'review',
 'small',
 'theres',
 'polls',
 'senator',
 'word',
 'open',
 'visit',
 'commanderinchief',
 'piece',
 'entire',
 'tampa',
 'play',
 'help',
 'supporting',
 'allow',
 'taking',
 'television',
 'hold',
 'living',
 'problem',
 'real',
 'good',
 'break',
 'favor',
 'care',
 'reason',
 'rest',
 'equal',
 'deals',
 'simple',
 'crowd',
 'group',
 'american',
 'force',
 'colorado',
 'create',
 'biden',
 '3pm',
 'statements',
 'drop',
 'highly',
 'lies',
 'hit',
 'men',
 'national',
 'senwarren',
 'crowds',
 'sees',
 'nh',
 'club',
 'world',
 'safety',
 'showing',
 'works',
 'tremendous',
 'gov',
 'elect',
 'want',
 'run',
 'attacks',
 'believe',
 'king',
 'fun',
 'raised',
 'wife',
 'solve',
 'celebrate',
 'politicians',
 'politician',
 'air',
 'playing',
 'sense',
 'breaking',
 'think',
 'signed',
 'led',
 'sixteen',
 'changing',
 'forget',
 'que',
 'friends',
 'deserves',
 'lead',
 'act',
 'democrats',
 'life',
 'nice',
 'moment',
 'loss',
 'businesses',
 'hands',
 'democrat',
 'left',
 'bring',
 'mess',
 'knew',
 'sign',
 'temperament',
 'understands',
 'fair',
 'cost',
 'sad',
 'spending',
 'started',
 'nomination',
 'kaine',
 'takes',
 'incredible',
 'easier',
 'daughter',
 'kindness',
 'leaders',
 'convention',
 'funny',
 'phony',
 'legal',
 'expand',
 'seventy',
 'answer',
 'leave',
 'desperate',
 'lose',
 'trade',
 'weve',
 'reckless',
 'losing',
 'months',
 'head',
 'saturday',
 'facing',
 'san',
 'order',
 'hits',
 'ted',
 'wanted',
 'rich',
 'bernie',
 'supports',
 'su',
 'thirteen',
 'meeting',
 'pass',
 'press',
 'spoke',
 'students',
 'power',
 'case',
 'millionaires',
 'shows',
 'letter',
 'billclinton',
 'old',
 'loved',
 'citizenship',
 'golf',
 'dead',
 'doesnt',
 'away',
 'en',
 'mitt',
 'friend',
 'los',
 'spend',
 'yesterday',
 'latinos',
 'close',
 'deal',
 'rubio',
 'media',
 'ideas',
 'mark',
 'presidency',
 'honored',
 'book',
 'standing',
 'rally',
 'bush',
 'event',
 'protecting',
 'shes',
 'shot',
 'especially',
 'supporters',
 'wrote',
 'thinks',
 'carson',
 'single',
 'goes',
 'fast',
 'best',
 'joebiden',
 'lgbt',
 'truly',
 'black',
 'prepared',
 'million',
 'hes',
 'email',
 'judge',
 'fantastic',
 'wsj',
 'majority',
 'leadership',
 'game',
 'fox',
 'try',
 'miami',
 'family',
 'looks',
 'treated',
 'matter',
 'came',
 'owner',
 'el',
 'billion',
 'showed',
 'turned',
 'dont',
 'attack',
 'experience',
 'gold',
 'wonderful',
 'different',
 'greatest',
 'tpp',
 'putin',
 'article',
 'class',
 'beautiful',
 'gave',
 'respected',
 'nbcnewsforum',
 'joenbc',
 'clear',
 'latest',
 'dumb',
 'successful',
 'middle',
 'center',
 'important',
 'talk',
 'cleveland',
 'endorsing',
 'higher',
 'city',
 'able',
 'rallies',
 'report',
 'funding',
 'seventeen',
 'trying',
 'timkaine',
 'received',
 'created',
 'stands',
 'winner',
 'david',
 'company',
 'democratic',
 'voters',
 'love',
 'parents',
 'second',
 'tweet',
 'interests',
 'tim',
 'ties',
 'start',
 'tv',
 'times',
 'exactly',
 'unity',
 'used',
 'values',
 'brought',
 'whats',
 'possible',
 'talking',
 'reporter',
 'debt',
 'wish',
 'profit',
 'child',
 'isis',
 'movement',
 'choice',
 'longer',
 'dream',
 'nasty',
 'loves',
 'town',
 'career',
 'happened',
 'seven',
 'share',
 'god',
 'democracy',
 'person',
 'interview',
 'issues',
 'charge',
 'wonder',
 'pretty',
 'eighty',
 'dangerous',
 'fix',
 'la',
 'yorkers',
 'del',
 'mass',
 'americans',
 '2nd',
 'speak',
 'free',
 'says',
 'fbi',
 'states',
 'dog',
 'gop',
 'abc',
 'dems',
 'terrorists',
 'allies',
 'ha',
 'correct',
 'vice',
 'march',
 'nearly',
 'es',
 'kids',
 'nafta',
 'service',
 'liar',
 'strength',
 'reviews',
 'helping',
 'huge',
 'leader',
 'including',
 'look',
 'ninety',
 'african',
 'ad',
 'happen',
 'tower',
 'face',
 'economy',
 'zika',
 'oval',
 'social',
 'work',
 'past',
 'failing',
 'trillion',
 'known',
 'woman',
 'seen',
 'based',
 'took',
 'historic',
 'candidates',
 'fear',
 'text',
 'appreciate',
 'charlotte',
 'beat',
 'easy']

# %%
[x for x in q4_miw if x not in q4_policy and x not in q4_target]
# Out:
# ['ratings',
#  'today',
#  'mayor',
#  'mate',
#  'helped',
#  'pick',
#  'using',
#  'thinking',
#  'instead',
#  'state',
#  'republicans',
#  'michael',
#  'review',
#  'small',
#  'theres',
#  'polls',
#  'senator',
#  'word',
#  'open',
#  'visit',
#  'commanderinchief',
#  'piece',
#  'entire',
#  'tampa',
#  'play',
#  'help',
#  'supporting',
#  'allow',
#  'taking',
#  'television',
#  'hold',
#  'living',
#  'problem',
#  'real',
#  'good',
#  'break',
#  'favor',
#  'care',
#  'reason',
#  'rest',
#  'equal',
#  'deals',
#  'simple',
#  'crowd',
#  'group',
#  'american',
#  'force',
#  'colorado',
#  'create',
#  'biden',
#  '3pm',
#  'statements',
#  'drop',
#  'highly',
#  'lies',
#  'hit',
#  'men',
#  'national',
#  'senwarren',
#  'crowds',
#  'sees',
#  'nh',
#  'club',
#  'world',
#  'safety',
#  'showing',
#  'works',
#  'tremendous',
#  'gov',
#  'elect',
#  'want',
#  'run',
#  'attacks',
#  'believe',
#  'king',
#  'fun',
#  'raised',
#  'wife',
#  'solve',
# ...

# %%
for w in avg_miw_occur.index:
    if w in q1_hashtag or w in q3_hashtag:
        theme_map[w] = "Hashtag"
    elif w in q2_policy or w in q3_policy or w in q4_policy:
        theme_map[w] = "Policy"
    elif w in q1_target or w in q2_target or w in q3_target or w in q4_target:
        theme_map[w] = "Target Opposition"
    elif w in q1_interaction or w in q2_interaction or w in q3_interaction or w in q4_interaction:
        theme_map[w] = "Interact with Supporters/Audience"

# %%
df["Theme"] = df["most_important_word"].map(theme_map)

# %%
df.head()
# Out:
#                    id          handle  \
# 0  780925634159796224  HillaryClinton
# 1  780916180899037184  HillaryClinton
# 2  780911564857761793  HillaryClinton
# 3  780907038650068994  HillaryClinton
# 4  780897419462602752  HillaryClinton
#
#                                                 text  is_retweet  \
# 0  The question in this election: Who can put the...       False
# 1  Last night, Donald Trump said not paying taxes...        True
# 2  Couldn't be more proud of @HillaryClinton. Her...        True
# 3  If we stand together, there's nothing we can't...       False
# 4  Both candidates were asked about how they'd co...       False
#
#   original_author                 time in_reply_to_screen_name  \
# 0             NaN  2016-09-28T00:22:34                     NaN
# 1        timkaine  2016-09-27T23:45:00                     NaN
# 2           POTUS  2016-09-27T23:26:40                     NaN
# 3             NaN  2016-09-27T23:08:41                     NaN
# ...

# %%
df.to_csv("data/")
